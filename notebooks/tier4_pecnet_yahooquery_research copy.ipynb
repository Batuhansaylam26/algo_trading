# %% [markdown]
# # Tier4 PECNet YahooQuery Research
#
# Bu notebook bilinçli olarak sade tutuldu:
#
# - Veri doğrudan `yahooquery` ile çekilir.
# - Feature engineering notebook içinde yapılır.
# - Feast, Kedro, Dagster, MLflow ve W&B kullanılmaz.
# - Tier4 PECNet mantığı notebook içinde eğitilir: target-history ile ilk ağ, residual-error korelasyonuyla cascade feature seçimi, sonra error network ve final network.

# %% [markdown]
# ## 1. Imports

# %%
from __future__ import annotations

import sys
from pathlib import Path
from typing import Any

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score
from yahooquery import Ticker

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
PECNETFRAMEWORK_PATH = PROJECT_ROOT / "pecnetframework"
if str(PECNETFRAMEWORK_PATH) not in sys.path:
    sys.path.insert(0, str(PECNETFRAMEWORK_PATH))

from pecnet.network import PecnetBuilder
from pecnet.preprocessing.DataPreprocessor import DataPreprocessor
from pecnet.utils import FeatureSelector, Utility

pd.options.display.max_columns = 120
plt.style.use("seaborn-v0_8-whitegrid")

# %% [markdown]
# ## 2. Config

# %%
SYMBOLS = ["TUPRS.IS"]
PERIOD = "5y"
INTERVAL = "1d"

FEATURE_COLUMNS = [
    "prev_open",
    "prev_high",
    "prev_low",
    "prev_volume",
    "calendar_gap_days",
    "month_sin_1",
    "month_cos_1",
    "month_sin_2",
    "month_cos_2",
    "day_sin_1",
    "day_cos_1",
    "day_sin_2",
    "day_cos_2",
    "day_of_year_sin_1",
    "day_of_year_cos_1",
    "day_of_year_sin_2",
    "day_of_year_cos_2",
]

PREPROCESS_PARAMS = {
    "sampling_periods": [1, 2, 4],
    "sampling_statistics": ["mean", 'std'],
    "sequence_size": 4,
    "error_sequence_size": 8,
    "wavelet_type": "haar",
    "test_ratio": 0.1,
    'scale_factor': 1.3,
    'target_normalization_type': 'window_mean',
    'conjoincy': False,
}

HYPERPARAMS = {
    "learning_rate": 0.001,
    "epoch_size": 500,
    "batch_size": 96,
    "hidden_units_sizes": [32, 64, 32, 16],
}

SELECTION_PARAMS = {
    "correlation_threshold": 0.08,
    "max_selected_features": 5,
}

# %% [markdown]
# ## 3. YahooQuery Data Pull

# %%
def _datetime_column(frame: pd.DataFrame) -> str | None:
    for column in ["date", "datetime", "level_1", "index"]:
        if column not in frame.columns:
            continue
        converted = pd.to_datetime(frame[column], errors="coerce", utc=True)
        if converted.notna().mean() >= 0.8:
            return column
    return None


def normalize_yahooquery_history(raw: pd.DataFrame, symbol: str) -> pd.DataFrame:
    if isinstance(raw, dict):
        raise RuntimeError(f"YahooQuery returned an error payload for {symbol}: {raw}")
    if raw is None or raw.empty:
        raise RuntimeError(f"YahooQuery returned no rows for {symbol}.")

    frame = raw.reset_index().copy()
    frame.columns = [str(column).lower() for column in frame.columns]

    date_column = _datetime_column(frame)
    if date_column is None:
        raise ValueError(f"Could not find a datetime column for {symbol}. Columns={list(frame.columns)}")
    if date_column != "date":
        frame = frame.rename(columns={date_column: "date"})

    if "symbol" not in frame.columns:
        frame["symbol"] = symbol
    else:
        frame["symbol"] = frame["symbol"].fillna(symbol).astype(str)

    required = ["symbol", "date", "open", "high", "low", "close", "volume"]
    missing = sorted(set(required).difference(frame.columns))
    if missing:
        raise ValueError(f"YahooQuery data for {symbol} is missing columns: {missing}. Columns={list(frame.columns)}")

    frame = frame[required].copy()
    frame["date"] = pd.to_datetime(frame["date"], errors="coerce", utc=True).dt.tz_convert(None)
    for column in ["open", "high", "low", "close", "volume"]:
        frame[column] = pd.to_numeric(frame[column], errors="coerce")
    frame = frame.dropna(subset=required).sort_values(["symbol", "date"])
    return frame.reset_index(drop=True)


def fetch_yahooquery_prices(
    symbols: list[str],
    *,
    period: str,
    interval: str,
) -> pd.DataFrame:
    frames = []
    for symbol in symbols:
        print(f"Fetching {symbol}...")
        raw = Ticker(symbol, asynchronous=False).history(period=period, interval=interval)
        frames.append(normalize_yahooquery_history(raw, symbol))
    if not frames:
        raise RuntimeError("No symbols were requested.")
    return pd.concat(frames, ignore_index=True).sort_values(["symbol", "date"]).reset_index(drop=True)

# %%
prices = fetch_yahooquery_prices(SYMBOLS, period=PERIOD, interval=INTERVAL)
print(f"rows={len(prices):,} symbols={prices['symbol'].nunique()}")
display(prices.groupby("symbol").agg(rows=("date", "size"), start=("date", "min"), end=("date", "max")))
display(prices.tail())
# Out:
# Fetching TUPRS.IS...
# rows=1,251 symbols=1
#           rows      start        end
# symbol
# TUPRS.IS  1251 2021-07-19 2026-07-17
#         symbol       date    open    high     low   close      volume
# 1246  TUPRS.IS 2026-07-10  264.25  270.00  262.25  267.00  25522430.0
# 1247  TUPRS.IS 2026-07-13  271.50  273.00  266.50  268.25  24414654.0
# 1248  TUPRS.IS 2026-07-14  270.00  273.50  267.75  270.75  24519320.0
# 1249  TUPRS.IS 2026-07-16  271.25  286.75  271.25  286.25  29371641.0
# 1250  TUPRS.IS 2026-07-17  287.00  288.50  283.25  285.25  11658178.0

# %% [markdown]
# ## 4. Feature Engineering

# %%
def fourier_terms(date: pd.Series, *, period: float, harmonics: tuple[int, ...], prefix: str) -> pd.DataFrame:
    values = date.astype(float)
    data = {}
    for harmonic in harmonics:
        angle = 2.0 * np.pi * harmonic * values / period
        data[f"{prefix}_sin_{harmonic}"] = np.sin(angle)
        data[f"{prefix}_cos_{harmonic}"] = np.cos(angle)
    return pd.DataFrame(data, index=date.index)

# %%
def fill_business_days_for_symbol(symbol_frame: pd.DataFrame) -> pd.DataFrame:
    print(f"Filling business days for {symbol_frame}...")
    symbol = str(symbol_frame.name)
    print(f"Filling business days for {symbol}...")
    symbol_frame = symbol_frame.sort_values("date").drop_duplicates("date", keep="last")
    grid = pd.DataFrame({"date": pd.bdate_range(symbol_frame["date"].min(), symbol_frame["date"].max())})
    filled = grid.merge(symbol_frame, on="date", how="left")
    filled["symbol"] = symbol
    filled["synthetic_row"] = filled["close"].isna()

    price_columns = ["open", "high", "low", "close", "volume"]
    filled[price_columns] = filled[price_columns].ffill().bfill()

    actual_segment = (~filled["synthetic_row"]).astype(int).cumsum()
    synthetic_run = filled.groupby(actual_segment).cumcount()
    previous_run = synthetic_run.shift(1).fillna(0).astype(int)
    filled["calendar_gap_days"] = np.where(
        filled["synthetic_row"],
        synthetic_run,
        np.where(previous_run > 0, previous_run, 0),
    ).astype(float)
    return filled

# %%
prices_copy = prices.copy()
gruplanmis = prices_copy.groupby("symbol", group_keys=False)

for isim, grup in gruplanmis:
    print(f"--- Grup: {isim} ---")
    display(grup) # Konsolda çalışıyorsan 'print(grup)' kullanabilirsin
# Out:
# --- Grup: TUPRS.IS ---
#         symbol       date        open        high         low       close  \
# 0     TUPRS.IS 2021-07-19   13.492857   13.492857   13.378571   13.400000
# 1     TUPRS.IS 2021-07-26   13.421428   13.457142   13.121428   13.150000
# 2     TUPRS.IS 2021-07-27   13.121428   13.214285   13.000000   13.192857
# 3     TUPRS.IS 2021-07-28   13.185714   13.285714   13.107142   13.128571
# 4     TUPRS.IS 2021-07-29   13.221428   13.457142   13.221428   13.442857
# ...        ...        ...         ...         ...         ...         ...
# 1246  TUPRS.IS 2026-07-10  264.250000  270.000000  262.250000  267.000000
# 1247  TUPRS.IS 2026-07-13  271.500000  273.000000  266.500000  268.250000
# 1248  TUPRS.IS 2026-07-14  270.000000  273.500000  267.750000  270.750000
# 1249  TUPRS.IS 2026-07-16  271.250000  286.750000  271.250000  286.250000
# 1250  TUPRS.IS 2026-07-17  287.000000  288.500000  283.250000  285.250000
#
#           volume
# 0      4664205.0
# 1     19031124.0
# 2     19472152.0
# 3     18230023.0
# 4     23116380.0
# ...          ...
# 1246  25522430.0
# 1247  24414654.0
# 1248  24519320.0
# 1249  29371641.0
# 1250  11658178.0
#
# [1251 rows x 7 columns]

# %%
def build_tier4_features(prices: pd.DataFrame) -> pd.DataFrame:
    filled = (
        prices.groupby("symbol", group_keys=False)
        .apply(fill_business_days_for_symbol)
        .reset_index(drop=True)
        .sort_values(["symbol", "date"])
    )
    print(f"rows={len(filled):,} symbols={filled['symbol'].nunique()}")
    display(filled)
    for column in ["open", "high", "low", "volume"]:
        filled[f"prev_{column}"] = filled.groupby("symbol")[column].shift(1)

    month_terms = fourier_terms(filled["date"].dt.month, period=12.0, harmonics=(1, 2), prefix="month")
    day_terms = fourier_terms(filled["date"].dt.day, period=31.0, harmonics=(1, 2), prefix="day")
    doy_terms = fourier_terms(filled["date"].dt.dayofyear, period=366.0, harmonics=(1, 2), prefix="day_of_year")
    enriched = pd.concat([filled, month_terms, day_terms, doy_terms], axis=1)
    print(f"rows={len(enriched):,} symbols={enriched['symbol'].nunique()}")
    model_frame = enriched.rename(columns={"symbol": "unique_id", "date": "ds", "close": "y"})
    model_frame = model_frame[["unique_id", "ds", "y", *FEATURE_COLUMNS]].copy()
    model_frame = model_frame.dropna(subset=["unique_id", "ds", "y", *FEATURE_COLUMNS])
    return model_frame.sort_values(["unique_id", "ds"]).reset_index(drop=True)

# %%
model_frame = build_tier4_features(prices)
print(f"model_rows={len(model_frame):,}")
display(model_frame.groupby("unique_id").agg(rows=("ds", "size"), start=("ds", "min"), end=("ds", "max")))
display(model_frame.tail())
# Out:
# Filling business days for            date        open        high         low       close      volume
# 0    2021-07-19   13.492857   13.492857   13.378571   13.400000   4664205.0
# 1    2021-07-26   13.421428   13.457142   13.121428   13.150000  19031124.0
# 2    2021-07-27   13.121428   13.214285   13.000000   13.192857  19472152.0
# 3    2021-07-28   13.185714   13.285714   13.107142   13.128571  18230023.0
# 4    2021-07-29   13.221428   13.457142   13.221428   13.442857  23116380.0
# ...         ...         ...         ...         ...         ...         ...
# 1246 2026-07-10  264.250000  270.000000  262.250000  267.000000  25522430.0
# 1247 2026-07-13  271.500000  273.000000  266.500000  268.250000  24414654.0
# 1248 2026-07-14  270.000000  273.500000  267.750000  270.750000  24519320.0
# 1249 2026-07-16  271.250000  286.750000  271.250000  286.250000  29371641.0
# 1250 2026-07-17  287.000000  288.500000  283.250000  285.250000  11658178.0
#
# [1251 rows x 6 columns]...
# Filling business days for TUPRS.IS...
# rows=1,305 symbols=1
#            date        open        high         low   close      volume  \
# 0    2021-07-19   13.492857   13.492857   13.378571   13.40   4664205.0
# 1    2021-07-20   13.492857   13.492857   13.378571   13.40   4664205.0
# 2    2021-07-21   13.492857   13.492857   13.378571   13.40   4664205.0
# 3    2021-07-22   13.492857   13.492857   13.378571   13.40   4664205.0
# 4    2021-07-23   13.492857   13.492857   13.378571   13.40   4664205.0
# ...         ...         ...         ...         ...     ...         ...
# 1300 2026-07-13  271.500000  273.000000  266.500000  268.25  24414654.0
# 1301 2026-07-14  270.000000  273.500000  267.750000  270.75  24519320.0
# 1302 2026-07-15  270.000000  273.500000  267.750000  270.75  24519320.0
# 1303 2026-07-16  271.250000  286.750000  271.250000  286.25  29371641.0
# 1304 2026-07-17  287.000000  288.500000  283.250000  285.25  11658178.0
#
#         symbol  synthetic_row  calendar_gap_days
# 0     TUPRS.IS          False                0.0
# 1     TUPRS.IS           True                1.0
# 2     TUPRS.IS           True                2.0
# 3     TUPRS.IS           True                3.0
# 4     TUPRS.IS           True                4.0
# ...        ...            ...                ...
# 1300  TUPRS.IS          False                0.0
# 1301  TUPRS.IS          False                0.0
# 1302  TUPRS.IS           True                1.0
# 1303  TUPRS.IS          False                1.0
# 1304  TUPRS.IS          False                0.0
#
# [1305 rows x 9 columns]
# rows=1,305 symbols=1
# model_rows=1,304
#            rows      start        end
# unique_id
# TUPRS.IS   1304 2021-07-20 2026-07-17
#      unique_id         ds       y  prev_open  prev_high  prev_low  \
# 1299  TUPRS.IS 2026-07-13  268.25     264.25     270.00    262.25
# 1300  TUPRS.IS 2026-07-14  270.75     271.50     273.00    266.50
# 1301  TUPRS.IS 2026-07-15  270.75     270.00     273.50    267.75
# 1302  TUPRS.IS 2026-07-16  286.25     270.00     273.50    267.75
# 1303  TUPRS.IS 2026-07-17  285.25     271.25     286.75    271.25
#
#       prev_volume  calendar_gap_days  month_sin_1  month_cos_1  month_sin_2  \
# 1299   25522430.0                0.0         -0.5    -0.866025     0.866025
# 1300   24414654.0                0.0         -0.5    -0.866025     0.866025
# 1301   24519320.0                1.0         -0.5    -0.866025     0.866025
# 1302   24519320.0                1.0         -0.5    -0.866025     0.866025
# 1303   29371641.0                0.0         -0.5    -0.866025     0.866025
#
#       month_cos_2  day_sin_1  day_cos_1  day_sin_2  day_cos_2  \
# 1299          0.5   0.485302  -0.874347  -0.848644   0.528964
# 1300          0.5   0.299363  -0.954139  -0.571268   0.820763
# 1301          0.5   0.101168  -0.994869  -0.201299   0.979530
# 1302          0.5  -0.101168  -0.994869   0.201299   0.979530
# 1303          0.5  -0.299363  -0.954139   0.571268   0.820763
#
#       day_of_year_sin_1  day_of_year_cos_1  day_of_year_sin_2  \
# 1299          -0.187719          -0.982223           0.368763
# 1300          -0.204552          -0.978856           0.400454
# 1301          -0.221325          -0.975200           0.431673
# 1302          -0.238033          -0.971257           0.462383
# 1303          -0.254671          -0.967028           0.492548
#
#       day_of_year_cos_2
# 1299           0.929523
# 1300           0.916317
# 1301           0.902030
# 1302           0.886680
# 1303           0.870285

# %% [markdown]
# ## 5. PECNet Tier4 Helpers

# %%
def preprocess_ticker(
    *,
    ticker_df: pd.DataFrame,
    ticker: str,
    feature_columns: list[str],
    preprocess_params: dict[str, Any],
) -> dict[str, Any]:
    dp = DataPreprocessor()
    dp.reset()
    ticker_df = ticker_df.sort_values("ds").copy()
    params = {**preprocess_params}
    test_ratio = float(params.get("test_ratio", 0.1))
    if not 0 < test_ratio < 1:
        raise ValueError(f"PECNet test_ratio must be between 0 and 1, got {test_ratio}.")
    params["test_ratio"] = test_ratio

    target_series = ticker_df["y"].to_numpy(dtype=float)
    X_train_target, X_test_target, y_train, y_test = dp.preprocess(data=target_series, **params)

    feature_X_trains = []
    feature_X_tests = []
    available_features = [column for column in feature_columns if column in ticker_df.columns]
    for column in available_features:
        X_train_feature, X_test_feature, _, _ = dp.preprocess(
            data=ticker_df[column].to_numpy(dtype=float),
            **params,
        )
        feature_X_trains.append(X_train_feature)
        feature_X_tests.append(X_test_feature)

    return {
        "ticker": ticker,
        "dates": ticker_df["ds"].reset_index(drop=True),
        "X_train_target": X_train_target,
        "X_test_target": X_test_target,
        "y_train": y_train,
        "y_test": y_test,
        "feature_X_trains": feature_X_trains,
        "feature_X_tests": feature_X_tests,
        "feature_names": available_features,
        "preprocess_params": params,
    }

# %%
def candidate_variable_inputs(ticker_data: dict[str, Any]) -> tuple[list[str], list[np.ndarray], list[np.ndarray]]:
    return (
        ["target_history", *ticker_data["feature_names"]],
        [ticker_data["X_train_target"], *ticker_data["feature_X_trains"]],
        [ticker_data["X_test_target"], *ticker_data["feature_X_tests"]],
    )


def selection_row(
    *,
    ticker: str,
    order: int,
    feature_index: int,
    feature_name: str,
    correlation: float | None,
    reference_name: str,
    threshold: float | None,
) -> dict[str, Any]:
    return {
        "ticker": ticker,
        "tier": "tier4",
        "strategy": "thesis_wavelet_error_compensated_fusion",
        "selection_order": order,
        "feature_index": feature_index,
        "feature_name": feature_name,
        "reference_name": reference_name,
        "correlation": correlation,
        "abs_correlation": abs(correlation) if correlation is not None else None,
        "threshold": threshold,
    }

# %%
def build_tier4_pecnet_variables(
    *,
    builder,
    ticker_data: dict[str, Any],
    selection_params: dict[str, Any],
) -> tuple[Any, list[np.ndarray], pd.DataFrame]:
    candidate_names, candidate_X_train, candidate_X_test = candidate_variable_inputs(ticker_data)
    print(f"Building tier4 pecnet variables for {ticker_data['ticker']} with {len(candidate_names)} candidates...")

    threshold = float(selection_params.get("correlation_threshold", 0.08))
    max_selected_features = selection_params.get("max_selected_features")
    max_selected_features = int(max_selected_features) if max_selected_features is not None else None
    selector = FeatureSelector(threshold=threshold)
    reference = ticker_data["y_train"]
    initial_network_setting = True
    rows = []

    while True:
        if max_selected_features is not None and len(rows) >= max_selected_features:
            break

        selected_index = selector.select_next(
            candidate_X_train,
            reference,
            force_include_best_if_first=initial_network_setting,
        )
        if selected_index is None:
            break

        builder.add_variable_network(
            candidate_X_train[selected_index],
            ticker_data["y_train"] if initial_network_setting else reference,
        )
        correlation = selector.get_last_corr_score()
        rows.append(
            selection_row(
                ticker=ticker_data["ticker"],
                order=len(rows) + 1,
                feature_index=selected_index,
                feature_name=candidate_names[selected_index],
                correlation=float(correlation) if correlation is not None else None,
                reference_name="target_y" if initial_network_setting else "residual_error",
                threshold=threshold,
            )
        )
        print(f"Added feature: {candidate_names[selected_index]} | corr: {correlation:.3f}")
        reference = builder.pecnet.get_target_values_for_current_variable_network()
        initial_network_setting = False

    if not rows:
        builder.add_variable_network(ticker_data["X_train_target"], ticker_data["y_train"])
        rows.append(
            selection_row(
                ticker=ticker_data["ticker"],
                order=1,
                feature_index=0,
                feature_name="target_history",
                correlation=None,
                reference_name="target_y",
                threshold=None,
            )
        )

    selected_X_test = [candidate_X_test[int(row["feature_index"])] for row in rows]
    return builder, selected_X_test, pd.DataFrame(rows)

# %%
def regression_metrics(actual: np.ndarray, predicted: np.ndarray) -> dict[str, float]:
    return {
        "mae": float(mean_absolute_error(actual, predicted)),
        "rmse": float(np.sqrt(mean_squared_error(actual, predicted))),
        "mape": float(mean_absolute_percentage_error(actual, predicted)),
        "r2": float(r2_score(actual, predicted)) if len(actual) > 1 else np.nan,
    }


def directional_metrics(joined: pd.DataFrame, full_df: pd.DataFrame) -> dict[str, float]:
    previous_close = (
        full_df[["unique_id", "ds", "y"]]
        .sort_values(["unique_id", "ds"])
        .assign(previous_y=lambda frame: frame.groupby("unique_id")["y"].shift(1))
    )
    eval_frame = joined.merge(previous_close[["unique_id", "ds", "previous_y"]], on=["unique_id", "ds"], how="left")
    actual_up = eval_frame["y"] > eval_frame["previous_y"]
    predicted_up = eval_frame["PECNet"] > eval_frame["previous_y"]
    valid = eval_frame["previous_y"].notna()
    if not valid.any():
        return {"long_accuracy": np.nan, "long_precision": np.nan, "long_recall": np.nan, "long_signal_rate": np.nan}
    tp = int((predicted_up & actual_up & valid).sum())
    fp = int((predicted_up & ~actual_up & valid).sum())
    fn = int((~predicted_up & actual_up & valid).sum())
    return {
        "long_accuracy": float((predicted_up[valid] == actual_up[valid]).mean()),
        "long_precision": float(tp / (tp + fp)) if (tp + fp) else 0.0,
        "long_recall": float(tp / (tp + fn)) if (tp + fn) else 0.0,
        "long_signal_rate": float(predicted_up[valid].mean()),
    }

# %% [markdown]
# ## 6. Train Tier4 PECNet

# %%
def to_numpy_vector(values: Any) -> np.ndarray:
    return values.detach().cpu().numpy().reshape(-1) if hasattr(values, "detach") else np.asarray(values).reshape(-1)


def maybe_restore_prediction_scale(predictions: np.ndarray, actual: np.ndarray) -> tuple[np.ndarray, dict[str, Any]]:
    predictions = np.asarray(predictions, dtype=float).reshape(-1)
    actual = np.asarray(actual, dtype=float).reshape(-1)
    scaler = getattr(DataPreprocessor(), "target_scaler", None)
    scale_coeff = getattr(scaler, "scale_coeff", None) if scaler is not None else None
    actual_median = float(np.nanmedian(np.abs(actual))) if len(actual) else np.nan
    raw_pred_median = float(np.nanmedian(np.abs(predictions))) if len(predictions) else np.nan
    debug = {
        "raw_pred_min": float(np.nanmin(predictions)) if len(predictions) else np.nan,
        "raw_pred_max": float(np.nanmax(predictions)) if len(predictions) else np.nan,
        "raw_pred_median_abs": raw_pred_median,
        "actual_min": float(np.nanmin(actual)) if len(actual) else np.nan,
        "actual_max": float(np.nanmax(actual)) if len(actual) else np.nan,
        "actual_median_abs": actual_median,
        "target_scale_coeff": float(scale_coeff) if scale_coeff is not None else np.nan,
        "scale_fallback_applied": False,
    }

    scaled_predictions = predictions
    if scale_coeff is not None and np.isfinite(actual_median) and np.isfinite(raw_pred_median):
        if actual_median > 20 and raw_pred_median < actual_median * 0.1:
            scaled_predictions = scaler.unscale1D(predictions.reshape(-1, 1)).reshape(-1)
            debug["scale_fallback_applied"] = True
            debug["scaled_pred_min"] = float(np.nanmin(scaled_predictions))
            debug["scaled_pred_max"] = float(np.nanmax(scaled_predictions))
            debug["scaled_pred_median_abs"] = float(np.nanmedian(np.abs(scaled_predictions)))
    return scaled_predictions, debug


def train_one_ticker_tier4(
    *,
    ticker: str,
    full_df: pd.DataFrame,
) -> tuple[Any, pd.DataFrame, pd.DataFrame, pd.DataFrame]:
    Utility.set_hyperparameters(
        learning_rate=HYPERPARAMS["learning_rate"],
        epoch_size=HYPERPARAMS["epoch_size"],
        batch_size=HYPERPARAMS["batch_size"],
        hidden_units_sizes=HYPERPARAMS["hidden_units_sizes"],
    )

    full_df = full_df.sort_values("ds").copy()
    ticker_data = preprocess_ticker(
        ticker_df=full_df,
        ticker=ticker,
        feature_columns=FEATURE_COLUMNS,
        preprocess_params=PREPROCESS_PARAMS,
    )
    builder, selected_X_test, selection = build_tier4_pecnet_variables(
        builder=PecnetBuilder(),
        ticker_data=ticker_data,
        selection_params=SELECTION_PARAMS,
    )
    display(selection)
    pecnet = builder.add_error_network().add_final_network().build()
    raw_predictions = to_numpy_vector(pecnet.predict(*selected_X_test, test_target=ticker_data["y_test"]))
    tomorrow_prediction = float(raw_predictions[-1]) if len(raw_predictions) else np.nan
    predictions = raw_predictions[:-1] if len(raw_predictions) > 1 else raw_predictions

    prediction_dates = full_df[["unique_id", "ds", "y"]].tail(len(predictions)).reset_index(drop=True)
    predictions, scale_debug = maybe_restore_prediction_scale(predictions, prediction_dates["y"].to_numpy())
    joined = prediction_dates.copy()
    joined["PECNet"] = predictions[-len(joined):]

    scale_debug_frame = pd.DataFrame([{ "ticker": ticker, **scale_debug }])
    display(scale_debug_frame)

    metrics = {
        "ticker": ticker,
        "pecnet_test_ratio": ticker_data["preprocess_params"]["test_ratio"],
        "pecnet_test_rows": len(joined),
        "tomorrow_prediction_raw": tomorrow_prediction,
        **scale_debug,
        **regression_metrics(joined["y"].to_numpy(), joined["PECNet"].to_numpy()),
        **directional_metrics(joined, full_df),
        "selected_features": ",".join(selection["feature_name"].tolist()),
    }
    return pecnet, joined, pd.DataFrame([metrics]), selection

# %%
models = {}
prediction_frames = []
metric_frames = []
selection_frames = []

for ticker, full_symbol_df in model_frame.groupby("unique_id", observed=True):
    print(f"Training tier4 PECNet for {ticker}...")
    model, joined, metrics, selection = train_one_ticker_tier4(
        ticker=str(ticker),
        full_df=full_symbol_df.copy(),
    )
    models[str(ticker)] = model
    prediction_frames.append(joined)
    metric_frames.append(metrics)
    selection_frames.append(selection)

predictions = pd.concat(prediction_frames, ignore_index=True)
metrics = pd.concat(metric_frames, ignore_index=True)
feature_selection = pd.concat(selection_frames, ignore_index=True)

display(metrics)
display(feature_selection)
# Out:
# Training tier4 PECNet for TUPRS.IS...
# DataPreprocessor Initialized
# DataPreprocessor Reset
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Initial data size: 1304 ------
# Building tier4 pecnet variables for TUPRS.IS with 18 candidates...
# Mode:  train  Cascaded Neural Network for frequency 0 and statistic 0 is working...
#
# [Variable_0_Network_0] Epoch 1/500 | Loss: 0.040068
# [Variable_0_Network_0] Epoch 11/500 | Loss: 0.000305
# [Variable_0_Network_0] Epoch 21/500 | Loss: 0.000210
# [Variable_0_Network_0] Epoch 31/500 | Loss: 0.000195
# [Variable_0_Network_0] Epoch 41/500 | Loss: 0.000181
# [Variable_0_Network_0] Epoch 51/500 | Loss: 0.000186
# [Variable_0_Network_0] Epoch 61/500 | Loss: 0.000183
# [Variable_0_Network_0] Epoch 71/500 | Loss: 0.000185
# [Variable_0_Network_0] Epoch 81/500 | Loss: 0.000203
# [Variable_0_Network_0] Epoch 91/500 | Loss: 0.000200
# [Variable_0_Network_0] Epoch 101/500 | Loss: 0.000183
# [Variable_0_Network_0] Epoch 111/500 | Loss: 0.000227
# [Variable_0_Network_0] Epoch 121/500 | Loss: 0.000181
# [Variable_0_Network_0] Epoch 131/500 | Loss: 0.000235
# [Variable_0_Network_0] Epoch 141/500 | Loss: 0.000180
# [Variable_0_Network_0] Epoch 151/500 | Loss: 0.000185
# [Variable_0_Network_0] Epoch 161/500 | Loss: 0.000179
# [Variable_0_Network_0] Epoch 171/500 | Loss: 0.000220
# [Variable_0_Network_0] Epoch 181/500 | Loss: 0.000182
# [Variable_0_Network_0] Epoch 191/500 | Loss: 0.000233
# [Variable_0_Network_0] Epoch 201/500 | Loss: 0.000232
# [Variable_0_Network_0] Epoch 211/500 | Loss: 0.000181
# [Variable_0_Network_0] Epoch 221/500 | Loss: 0.000211
# [Variable_0_Network_0] Epoch 231/500 | Loss: 0.000177
# [Variable_0_Network_0] Epoch 241/500 | Loss: 0.000224
# [Variable_0_Network_0] Epoch 251/500 | Loss: 0.000203
# [Variable_0_Network_0] Epoch 261/500 | Loss: 0.000220
# [Variable_0_Network_0] Epoch 271/500 | Loss: 0.000288
# [Variable_0_Network_0] Epoch 281/500 | Loss: 0.000254
# [Variable_0_Network_0] Epoch 291/500 | Loss: 0.000254
# [Variable_0_Network_0] Epoch 301/500 | Loss: 0.000191
# [Variable_0_Network_0] Epoch 311/500 | Loss: 0.000201
# [Variable_0_Network_0] Epoch 321/500 | Loss: 0.000208
# [Variable_0_Network_0] Epoch 331/500 | Loss: 0.000181
# [Variable_0_Network_0] Epoch 341/500 | Loss: 0.000246
# [Variable_0_Network_0] Epoch 351/500 | Loss: 0.000183
# [Variable_0_Network_0] Epoch 361/500 | Loss: 0.000189
# [Variable_0_Network_0] Epoch 371/500 | Loss: 0.000183
# [Variable_0_Network_0] Epoch 381/500 | Loss: 0.000177
# [Variable_0_Network_0] Epoch 391/500 | Loss: 0.000180
# [Variable_0_Network_0] Epoch 401/500 | Loss: 0.000187
# [Variable_0_Network_0] Epoch 411/500 | Loss: 0.000194
# [Variable_0_Network_0] Epoch 421/500 | Loss: 0.000200
# [Variable_0_Network_0] Epoch 431/500 | Loss: 0.000178
# [Variable_0_Network_0] Epoch 441/500 | Loss: 0.000212
# [Variable_0_Network_0] Epoch 451/500 | Loss: 0.000193
# [Variable_0_Network_0] Epoch 461/500 | Loss: 0.000179
# [Variable_0_Network_0] Epoch 471/500 | Loss: 0.000206
# [Variable_0_Network_0] Epoch 481/500 | Loss: 0.000182
# [Variable_0_Network_0] Epoch 491/500 | Loss: 0.000200
# [Variable_0_Network_0] Epoch 500/500 | Loss: 0.000179
#
# Loss curve saved to /workspaces/yahooquery_lakehouse_revamp/pecnetframework/pecnet/logs/Variable_0_Network_0_lossplot.png
#
# Mode:  train  Cascaded Neural Network for frequency 0 and statistic 1 is working...
#
# [Variable_0_Network_1] Epoch 1/500 | Loss: 0.018216
# [Variable_0_Network_1] Epoch 11/500 | Loss: 0.000185
# [Variable_0_Network_1] Epoch 21/500 | Loss: 0.000181
# [Variable_0_Network_1] Epoch 31/500 | Loss: 0.000178
# [Variable_0_Network_1] Epoch 41/500 | Loss: 0.000192
# [Variable_0_Network_1] Epoch 51/500 | Loss: 0.000178
# [Variable_0_Network_1] Epoch 61/500 | Loss: 0.000196
# [Variable_0_Network_1] Epoch 71/500 | Loss: 0.000174
# [Variable_0_Network_1] Epoch 81/500 | Loss: 0.000185
# [Variable_0_Network_1] Epoch 91/500 | Loss: 0.000176
# [Variable_0_Network_1] Epoch 101/500 | Loss: 0.000191
# [Variable_0_Network_1] Epoch 111/500 | Loss: 0.000187
# [Variable_0_Network_1] Epoch 121/500 | Loss: 0.000203
# [Variable_0_Network_1] Epoch 131/500 | Loss: 0.000172
# [Variable_0_Network_1] Epoch 141/500 | Loss: 0.000175
# [Variable_0_Network_1] Epoch 151/500 | Loss: 0.000188
# [Variable_0_Network_1] Epoch 161/500 | Loss: 0.000173
# [Variable_0_Network_1] Epoch 171/500 | Loss: 0.000180
# [Variable_0_Network_1] Epoch 181/500 | Loss: 0.000177
# [Variable_0_Network_1] Epoch 191/500 | Loss: 0.000174
# [Variable_0_Network_1] Epoch 201/500 | Loss: 0.000174
# [Variable_0_Network_1] Epoch 211/500 | Loss: 0.000176
# [Variable_0_Network_1] Epoch 221/500 | Loss: 0.000190
# [Variable_0_Network_1] Epoch 231/500 | Loss: 0.000187
# [Variable_0_Network_1] Epoch 241/500 | Loss: 0.000184
# [Variable_0_Network_1] Epoch 251/500 | Loss: 0.000188
# [Variable_0_Network_1] Epoch 261/500 | Loss: 0.000178
# [Variable_0_Network_1] Epoch 271/500 | Loss: 0.000250
# [Variable_0_Network_1] Epoch 281/500 | Loss: 0.000250
# [Variable_0_Network_1] Epoch 291/500 | Loss: 0.000175
# [Variable_0_Network_1] Epoch 301/500 | Loss: 0.000177
# [Variable_0_Network_1] Epoch 311/500 | Loss: 0.000175
# [Variable_0_Network_1] Epoch 321/500 | Loss: 0.000182
# [Variable_0_Network_1] Epoch 331/500 | Loss: 0.000184
# [Variable_0_Network_1] Epoch 341/500 | Loss: 0.000182
# [Variable_0_Network_1] Epoch 351/500 | Loss: 0.000180
# [Variable_0_Network_1] Epoch 361/500 | Loss: 0.000189
# [Variable_0_Network_1] Epoch 371/500 | Loss: 0.000176
# [Variable_0_Network_1] Epoch 381/500 | Loss: 0.000185
# [Variable_0_Network_1] Epoch 391/500 | Loss: 0.000186
# [Variable_0_Network_1] Epoch 401/500 | Loss: 0.000199
# [Variable_0_Network_1] Epoch 411/500 | Loss: 0.000180
# [Variable_0_Network_1] Epoch 421/500 | Loss: 0.000183
# [Variable_0_Network_1] Epoch 431/500 | Loss: 0.000179
# [Variable_0_Network_1] Epoch 441/500 | Loss: 0.000176
# [Variable_0_Network_1] Epoch 451/500 | Loss: 0.000217
# [Variable_0_Network_1] Epoch 461/500 | Loss: 0.000176
# [Variable_0_Network_1] Epoch 471/500 | Loss: 0.000183
# [Variable_0_Network_1] Epoch 481/500 | Loss: 0.000194
# [Variable_0_Network_1] Epoch 491/500 | Loss: 0.000189
# [Variable_0_Network_1] Epoch 500/500 | Loss: 0.000179
#
# Loss curve saved to /workspaces/yahooquery_lakehouse_revamp/pecnetframework/pecnet/logs/Variable_0_Network_1_lossplot.png
#
# Mode:  train  Cascaded Neural Network for frequency 1 and statistic 0 is working...
#
# [Variable_0_Network_2] Epoch 1/500 | Loss: 0.118891
# [Variable_0_Network_2] Epoch 11/500 | Loss: 0.000198
# [Variable_0_Network_2] Epoch 21/500 | Loss: 0.000162
# [Variable_0_Network_2] Epoch 31/500 | Loss: 0.000144
# [Variable_0_Network_2] Epoch 41/500 | Loss: 0.000135
# [Variable_0_Network_2] Epoch 51/500 | Loss: 0.000128
# [Variable_0_Network_2] Epoch 61/500 | Loss: 0.000131
# [Variable_0_Network_2] Epoch 71/500 | Loss: 0.000127
# [Variable_0_Network_2] Epoch 81/500 | Loss: 0.000127
# [Variable_0_Network_2] Epoch 91/500 | Loss: 0.000123
# [Variable_0_Network_2] Epoch 101/500 | Loss: 0.000123
# [Variable_0_Network_2] Epoch 111/500 | Loss: 0.000123
# [Variable_0_Network_2] Epoch 121/500 | Loss: 0.000125
# [Variable_0_Network_2] Epoch 131/500 | Loss: 0.000129
# [Variable_0_Network_2] Epoch 141/500 | Loss: 0.000129
# [Variable_0_Network_2] Epoch 151/500 | Loss: 0.000129
# [Variable_0_Network_2] Epoch 161/500 | Loss: 0.000134
# [Variable_0_Network_2] Epoch 171/500 | Loss: 0.000127
# [Variable_0_Network_2] Epoch 181/500 | Loss: 0.000132
# [Variable_0_Network_2] Epoch 191/500 | Loss: 0.000123
# [Variable_0_Network_2] Epoch 201/500 | Loss: 0.000123
# [Variable_0_Network_2] Epoch 211/500 | Loss: 0.000138
# [Variable_0_Network_2] Epoch 221/500 | Loss: 0.000143
# [Variable_0_Network_2] Epoch 231/500 | Loss: 0.000151
# [Variable_0_Network_2] Epoch 241/500 | Loss: 0.000163
# [Variable_0_Network_2] Epoch 251/500 | Loss: 0.000130
# [Variable_0_Network_2] Epoch 261/500 | Loss: 0.000134
# [Variable_0_Network_2] Epoch 271/500 | Loss: 0.000128
# [Variable_0_Network_2] Epoch 281/500 | Loss: 0.000163
# [Variable_0_Network_2] Epoch 291/500 | Loss: 0.000169
# [Variable_0_Network_2] Epoch 301/500 | Loss: 0.000131
# [Variable_0_Network_2] Epoch 311/500 | Loss: 0.000127
# [Variable_0_Network_2] Epoch 321/500 | Loss: 0.000129
# [Variable_0_Network_2] Epoch 331/500 | Loss: 0.000130
# [Variable_0_Network_2] Epoch 341/500 | Loss: 0.000137
# [Variable_0_Network_2] Epoch 351/500 | Loss: 0.000187
# [Variable_0_Network_2] Epoch 361/500 | Loss: 0.000186
# [Variable_0_Network_2] Epoch 371/500 | Loss: 0.000166
# [Variable_0_Network_2] Epoch 381/500 | Loss: 0.000168
# [Variable_0_Network_2] Epoch 391/500 | Loss: 0.000135
# [Variable_0_Network_2] Epoch 401/500 | Loss: 0.000130
# [Variable_0_Network_2] Epoch 411/500 | Loss: 0.000129
# [Variable_0_Network_2] Epoch 421/500 | Loss: 0.000128
# [Variable_0_Network_2] Epoch 431/500 | Loss: 0.000170
# [Variable_0_Network_2] Epoch 441/500 | Loss: 0.000130
# [Variable_0_Network_2] Epoch 451/500 | Loss: 0.000130
# [Variable_0_Network_2] Epoch 461/500 | Loss: 0.000141
# [Variable_0_Network_2] Epoch 471/500 | Loss: 0.000138
# [Variable_0_Network_2] Epoch 481/500 | Loss: 0.000130
# [Variable_0_Network_2] Epoch 491/500 | Loss: 0.000177
# [Variable_0_Network_2] Epoch 500/500 | Loss: 0.000135
#
# Loss curve saved to /workspaces/yahooquery_lakehouse_revamp/pecnetframework/pecnet/logs/Variable_0_Network_2_lossplot.png
#
# Mode:  train  Cascaded Neural Network for frequency 1 and statistic 1 is working...
#
# [Variable_0_Network_3] Epoch 1/500 | Loss: 0.110397
# [Variable_0_Network_3] Epoch 11/500 | Loss: 0.000141
# [Variable_0_Network_3] Epoch 21/500 | Loss: 0.000138
# [Variable_0_Network_3] Epoch 31/500 | Loss: 0.000134
# [Variable_0_Network_3] Epoch 41/500 | Loss: 0.000132
# [Variable_0_Network_3] Epoch 51/500 | Loss: 0.000130
# [Variable_0_Network_3] Epoch 61/500 | Loss: 0.000133
# [Variable_0_Network_3] Epoch 71/500 | Loss: 0.000129
# [Variable_0_Network_3] Epoch 81/500 | Loss: 0.000127
# [Variable_0_Network_3] Epoch 91/500 | Loss: 0.000128
# [Variable_0_Network_3] Epoch 101/500 | Loss: 0.000134
# [Variable_0_Network_3] Epoch 111/500 | Loss: 0.000125
# [Variable_0_Network_3] Epoch 121/500 | Loss: 0.000128
# [Variable_0_Network_3] Epoch 131/500 | Loss: 0.000125
# [Variable_0_Network_3] Epoch 141/500 | Loss: 0.000128
# [Variable_0_Network_3] Epoch 151/500 | Loss: 0.000127
# [Variable_0_Network_3] Epoch 161/500 | Loss: 0.000128
# [Variable_0_Network_3] Epoch 171/500 | Loss: 0.000126
# [Variable_0_Network_3] Epoch 181/500 | Loss: 0.000128
# [Variable_0_Network_3] Epoch 191/500 | Loss: 0.000129
# [Variable_0_Network_3] Epoch 201/500 | Loss: 0.000135
# [Variable_0_Network_3] Epoch 211/500 | Loss: 0.000128
# [Variable_0_Network_3] Epoch 221/500 | Loss: 0.000136
# [Variable_0_Network_3] Epoch 231/500 | Loss: 0.000131
# [Variable_0_Network_3] Epoch 241/500 | Loss: 0.000129
# [Variable_0_Network_3] Epoch 251/500 | Loss: 0.000127
# [Variable_0_Network_3] Epoch 261/500 | Loss: 0.000143
# [Variable_0_Network_3] Epoch 271/500 | Loss: 0.000127
# [Variable_0_Network_3] Epoch 281/500 | Loss: 0.000125
# [Variable_0_Network_3] Epoch 291/500 | Loss: 0.000126
# [Variable_0_Network_3] Epoch 301/500 | Loss: 0.000124
# [Variable_0_Network_3] Epoch 311/500 | Loss: 0.000131
# [Variable_0_Network_3] Epoch 321/500 | Loss: 0.000161
# [Variable_0_Network_3] Epoch 331/500 | Loss: 0.000126
# [Variable_0_Network_3] Epoch 341/500 | Loss: 0.000126
# [Variable_0_Network_3] Epoch 351/500 | Loss: 0.000132
# [Variable_0_Network_3] Epoch 361/500 | Loss: 0.000136
# [Variable_0_Network_3] Epoch 371/500 | Loss: 0.000130
# [Variable_0_Network_3] Epoch 381/500 | Loss: 0.000126
# [Variable_0_Network_3] Epoch 391/500 | Loss: 0.000138
# [Variable_0_Network_3] Epoch 401/500 | Loss: 0.000133
# [Variable_0_Network_3] Epoch 411/500 | Loss: 0.000137
# [Variable_0_Network_3] Epoch 421/500 | Loss: 0.000157
# [Variable_0_Network_3] Epoch 431/500 | Loss: 0.000131
# [Variable_0_Network_3] Epoch 441/500 | Loss: 0.000128
# [Variable_0_Network_3] Epoch 451/500 | Loss: 0.000135
# [Variable_0_Network_3] Epoch 461/500 | Loss: 0.000131
# [Variable_0_Network_3] Epoch 471/500 | Loss: 0.000126
# [Variable_0_Network_3] Epoch 481/500 | Loss: 0.000132
# [Variable_0_Network_3] Epoch 491/500 | Loss: 0.000149
# [Variable_0_Network_3] Epoch 500/500 | Loss: 0.000133
#
# Loss curve saved to /workspaces/yahooquery_lakehouse_revamp/pecnetframework/pecnet/logs/Variable_0_Network_3_lossplot.png
#
# Mode:  train  Cascaded Neural Network for frequency 2 and statistic 0 is working...
#
# [Variable_0_Network_4] Epoch 1/500 | Loss: 0.033291
# [Variable_0_Network_4] Epoch 11/500 | Loss: 0.000211
# [Variable_0_Network_4] Epoch 21/500 | Loss: 0.000161
# [Variable_0_Network_4] Epoch 31/500 | Loss: 0.000121
# [Variable_0_Network_4] Epoch 41/500 | Loss: 0.000107
# [Variable_0_Network_4] Epoch 51/500 | Loss: 0.000104
# [Variable_0_Network_4] Epoch 61/500 | Loss: 0.000102
# [Variable_0_Network_4] Epoch 71/500 | Loss: 0.000101
# [Variable_0_Network_4] Epoch 81/500 | Loss: 0.000108
# [Variable_0_Network_4] Epoch 91/500 | Loss: 0.000100
# [Variable_0_Network_4] Epoch 101/500 | Loss: 0.000097
# [Variable_0_Network_4] Epoch 111/500 | Loss: 0.000099
# [Variable_0_Network_4] Epoch 121/500 | Loss: 0.000098
# [Variable_0_Network_4] Epoch 131/500 | Loss: 0.000101
# [Variable_0_Network_4] Epoch 141/500 | Loss: 0.000110
# [Variable_0_Network_4] Epoch 151/500 | Loss: 0.000096
# [Variable_0_Network_4] Epoch 161/500 | Loss: 0.000098
# [Variable_0_Network_4] Epoch 171/500 | Loss: 0.000123
# [Variable_0_Network_4] Epoch 181/500 | Loss: 0.000115
# [Variable_0_Network_4] Epoch 191/500 | Loss: 0.000115
# [Variable_0_Network_4] Epoch 201/500 | Loss: 0.000136
# [Variable_0_Network_4] Epoch 211/500 | Loss: 0.000104
# [Variable_0_Network_4] Epoch 221/500 | Loss: 0.000100
# [Variable_0_Network_4] Epoch 231/500 | Loss: 0.000099
# [Variable_0_Network_4] Epoch 241/500 | Loss: 0.000097
# [Variable_0_Network_4] Epoch 251/500 | Loss: 0.000099
# [Variable_0_Network_4] Epoch 261/500 | Loss: 0.000099
# [Variable_0_Network_4] Epoch 271/500 | Loss: 0.000099
# [Variable_0_Network_4] Epoch 281/500 | Loss: 0.000116
# [Variable_0_Network_4] Epoch 291/500 | Loss: 0.000100
# [Variable_0_Network_4] Epoch 301/500 | Loss: 0.000100
# [Variable_0_Network_4] Epoch 311/500 | Loss: 0.000105
# [Variable_0_Network_4] Epoch 321/500 | Loss: 0.000099
# [Variable_0_Network_4] Epoch 331/500 | Loss: 0.000096
# [Variable_0_Network_4] Epoch 341/500 | Loss: 0.000101
# [Variable_0_Network_4] Epoch 351/500 | Loss: 0.000116
# [Variable_0_Network_4] Epoch 361/500 | Loss: 0.000127
# [Variable_0_Network_4] Epoch 371/500 | Loss: 0.000116
# [Variable_0_Network_4] Epoch 381/500 | Loss: 0.000104
# [Variable_0_Network_4] Epoch 391/500 | Loss: 0.000102
# [Variable_0_Network_4] Epoch 401/500 | Loss: 0.000105
# [Variable_0_Network_4] Epoch 411/500 | Loss: 0.000148
# [Variable_0_Network_4] Epoch 421/500 | Loss: 0.000110
# [Variable_0_Network_4] Epoch 431/500 | Loss: 0.000122
# [Variable_0_Network_4] Epoch 441/500 | Loss: 0.000104
# [Variable_0_Network_4] Epoch 451/500 | Loss: 0.000101
# [Variable_0_Network_4] Epoch 461/500 | Loss: 0.000108
# [Variable_0_Network_4] Epoch 471/500 | Loss: 0.000112
# [Variable_0_Network_4] Epoch 481/500 | Loss: 0.000108
# [Variable_0_Network_4] Epoch 491/500 | Loss: 0.000100
# [Variable_0_Network_4] Epoch 500/500 | Loss: 0.000104
#
# Loss curve saved to /workspaces/yahooquery_lakehouse_revamp/pecnetframework/pecnet/logs/Variable_0_Network_4_lossplot.png
#
# Added feature: target_history | corr: -0.683
#      ticker   tier                                 strategy  selection_order  \
# 0  TUPRS.IS  tier4  thesis_wavelet_error_compensated_fusion                1
#
#    feature_index    feature_name reference_name  correlation  abs_correlation  \
# 0              0  target_history       target_y    -0.682953         0.682953
#
#    threshold
# 0       0.08
# Mode:  train  Error Network is working...
#
# [ErrorNetwork] Epoch 1/500 | Loss: 0.013896
# [ErrorNetwork] Epoch 11/500 | Loss: 0.000228
# [ErrorNetwork] Epoch 21/500 | Loss: 0.000516
# [ErrorNetwork] Epoch 31/500 | Loss: 0.000224
# [ErrorNetwork] Epoch 41/500 | Loss: 0.000158
# [ErrorNetwork] Epoch 51/500 | Loss: 0.000209
# [ErrorNetwork] Epoch 61/500 | Loss: 0.000187
# [ErrorNetwork] Epoch 71/500 | Loss: 0.000303
# [ErrorNetwork] Epoch 81/500 | Loss: 0.000185
# [ErrorNetwork] Epoch 91/500 | Loss: 0.000209
# [ErrorNetwork] Epoch 101/500 | Loss: 0.000167
# [ErrorNetwork] Epoch 111/500 | Loss: 0.000403
# [ErrorNetwork] Epoch 121/500 | Loss: 0.000143
# [ErrorNetwork] Epoch 131/500 | Loss: 0.000154
# [ErrorNetwork] Epoch 141/500 | Loss: 0.000315
# [ErrorNetwork] Epoch 151/500 | Loss: 0.000164
# [ErrorNetwork] Epoch 161/500 | Loss: 0.000191
# [ErrorNetwork] Epoch 171/500 | Loss: 0.000181
# [ErrorNetwork] Epoch 181/500 | Loss: 0.000147
# [ErrorNetwork] Epoch 191/500 | Loss: 0.000354
# [ErrorNetwork] Epoch 201/500 | Loss: 0.000143
# [ErrorNetwork] Epoch 211/500 | Loss: 0.000158
# [ErrorNetwork] Epoch 221/500 | Loss: 0.000233
# [ErrorNetwork] Epoch 231/500 | Loss: 0.000215
# [ErrorNetwork] Epoch 241/500 | Loss: 0.000237
# [ErrorNetwork] Epoch 251/500 | Loss: 0.000350
# [ErrorNetwork] Epoch 261/500 | Loss: 0.000165
# [ErrorNetwork] Epoch 271/500 | Loss: 0.000165
# [ErrorNetwork] Epoch 281/500 | Loss: 0.000214
# [ErrorNetwork] Epoch 291/500 | Loss: 0.000170
# [ErrorNetwork] Epoch 301/500 | Loss: 0.000154
# [ErrorNetwork] Epoch 311/500 | Loss: 0.000197
# [ErrorNetwork] Epoch 321/500 | Loss: 0.000155
# [ErrorNetwork] Epoch 331/500 | Loss: 0.000177
# [ErrorNetwork] Epoch 341/500 | Loss: 0.000143
# [ErrorNetwork] Epoch 351/500 | Loss: 0.000152
# [ErrorNetwork] Epoch 361/500 | Loss: 0.000155
# [ErrorNetwork] Epoch 371/500 | Loss: 0.000199
# [ErrorNetwork] Epoch 381/500 | Loss: 0.000164
# [ErrorNetwork] Epoch 391/500 | Loss: 0.000149
# [ErrorNetwork] Epoch 401/500 | Loss: 0.000145
# [ErrorNetwork] Epoch 411/500 | Loss: 0.000268
# [ErrorNetwork] Epoch 421/500 | Loss: 0.000166
# [ErrorNetwork] Epoch 431/500 | Loss: 0.000180
# [ErrorNetwork] Epoch 441/500 | Loss: 0.000554
# [ErrorNetwork] Epoch 451/500 | Loss: 0.000501
# [ErrorNetwork] Epoch 461/500 | Loss: 0.000231
# [ErrorNetwork] Epoch 471/500 | Loss: 0.000305
# [ErrorNetwork] Epoch 481/500 | Loss: 0.000149
# [ErrorNetwork] Epoch 491/500 | Loss: 0.000175
# [ErrorNetwork] Epoch 500/500 | Loss: 0.000152
#
# Loss curve saved to /workspaces/yahooquery_lakehouse_revamp/pecnetframework/pecnet/logs/ErrorNetwork_lossplot.png
#
# Mode:  train  Final Network is working...
#
# [FinalNetwork] Epoch 1/500 | Loss: 0.013535
# [FinalNetwork] Epoch 11/500 | Loss: 0.000006
# [FinalNetwork] Epoch 21/500 | Loss: 0.000005
# [FinalNetwork] Epoch 31/500 | Loss: 0.000004
# [FinalNetwork] Epoch 41/500 | Loss: 0.000004
# [FinalNetwork] Epoch 51/500 | Loss: 0.000003
# [FinalNetwork] Epoch 61/500 | Loss: 0.000002
# [FinalNetwork] Epoch 71/500 | Loss: 0.000002
# [FinalNetwork] Epoch 81/500 | Loss: 0.000002
# [FinalNetwork] Epoch 91/500 | Loss: 0.000002
# [FinalNetwork] Epoch 101/500 | Loss: 0.000002
# [FinalNetwork] Epoch 111/500 | Loss: 0.000003
# [FinalNetwork] Epoch 121/500 | Loss: 0.000002
# [FinalNetwork] Epoch 131/500 | Loss: 0.000002
# [FinalNetwork] Epoch 141/500 | Loss: 0.000002
# [FinalNetwork] Epoch 151/500 | Loss: 0.000003
# [FinalNetwork] Epoch 161/500 | Loss: 0.000005
# [FinalNetwork] Epoch 171/500 | Loss: 0.000003
# [FinalNetwork] Epoch 181/500 | Loss: 0.000003
# [FinalNetwork] Epoch 191/500 | Loss: 0.000006
# [FinalNetwork] Epoch 201/500 | Loss: 0.000001
# [FinalNetwork] Epoch 211/500 | Loss: 0.000002
# [FinalNetwork] Epoch 221/500 | Loss: 0.000002
# [FinalNetwork] Epoch 231/500 | Loss: 0.000008
# [FinalNetwork] Epoch 241/500 | Loss: 0.000003
# [FinalNetwork] Epoch 251/500 | Loss: 0.000006
# [FinalNetwork] Epoch 261/500 | Loss: 0.000001
# [FinalNetwork] Epoch 271/500 | Loss: 0.000003
# [FinalNetwork] Epoch 281/500 | Loss: 0.000001
# [FinalNetwork] Epoch 291/500 | Loss: 0.000006
# [FinalNetwork] Epoch 301/500 | Loss: 0.000022
# [FinalNetwork] Epoch 311/500 | Loss: 0.000001
# [FinalNetwork] Epoch 321/500 | Loss: 0.000003
# [FinalNetwork] Epoch 331/500 | Loss: 0.000001
# [FinalNetwork] Epoch 341/500 | Loss: 0.000006
# [FinalNetwork] Epoch 351/500 | Loss: 0.000009
# [FinalNetwork] Epoch 361/500 | Loss: 0.000003
# [FinalNetwork] Epoch 371/500 | Loss: 0.000007
# [FinalNetwork] Epoch 381/500 | Loss: 0.000003
# [FinalNetwork] Epoch 391/500 | Loss: 0.000006
# [FinalNetwork] Epoch 401/500 | Loss: 0.000001
# [FinalNetwork] Epoch 411/500 | Loss: 0.000011
# [FinalNetwork] Epoch 421/500 | Loss: 0.000002
# [FinalNetwork] Epoch 431/500 | Loss: 0.000002
# [FinalNetwork] Epoch 441/500 | Loss: 0.000003
# [FinalNetwork] Epoch 451/500 | Loss: 0.000006
# [FinalNetwork] Epoch 461/500 | Loss: 0.000010
# [FinalNetwork] Epoch 471/500 | Loss: 0.000006
# [FinalNetwork] Epoch 481/500 | Loss: 0.000003
# [FinalNetwork] Epoch 491/500 | Loss: 0.000006
# [FinalNetwork] Epoch 500/500 | Loss: 0.000008
#
# Loss curve saved to /workspaces/yahooquery_lakehouse_revamp/pecnetframework/pecnet/logs/FinalNetwork_lossplot.png
#
# Mode:  test  Cascaded Neural Network for frequency 0 and statistic 0 is working...
#
# Mode:  test  Cascaded Neural Network for frequency 0 and statistic 1 is working...
#
# Mode:  test  Cascaded Neural Network for frequency 1 and statistic 0 is working...
#
# Mode:  test  Cascaded Neural Network for frequency 1 and statistic 1 is working...
#
# Mode:  test  Cascaded Neural Network for frequency 2 and statistic 0 is working...
#
# Mode:  test  Error Network is working...
#
# Mode:  test  Final Network is working...
#      ticker  raw_pred_min  raw_pred_max  raw_pred_median_abs  actual_min  \
# 0  TUPRS.IS     -0.548081      1.440406             0.516078  214.399994
#
#    actual_max  actual_median_abs  target_scale_coeff  scale_fallback_applied  \
# 0      286.25         248.300003           277.90285                    True
#
#    scaled_pred_min  scaled_pred_max  scaled_pred_median_abs
# 0      -152.313345       400.293013              143.419511
#      ticker  pecnet_test_ratio  pecnet_test_rows  tomorrow_prediction_raw  \
# 0  TUPRS.IS                0.1               119                 1.265756
#
#    raw_pred_min  raw_pred_max  raw_pred_median_abs  actual_min  actual_max  \
# 0     -0.548081      1.440406             0.516078  214.399994      286.25
#
#    actual_median_abs  target_scale_coeff  scale_fallback_applied  \
# 0         248.300003           277.90285                    True
#
#    scaled_pred_min  scaled_pred_max  scaled_pred_median_abs         mae  \
# 0      -152.313345       400.293013              143.419511  193.545259
#
#          rmse      mape          r2  long_accuracy  long_precision  \
# 0  229.941397  0.768293 -166.079812       0.521008             0.5
#
#    long_recall  long_signal_rate selected_features
# 0     0.385965          0.369748    target_history
#      ticker   tier                                 strategy  selection_order  \
# 0  TUPRS.IS  tier4  thesis_wavelet_error_compensated_fusion                1
#
#    feature_index    feature_name reference_name  correlation  abs_correlation  \
# 0              0  target_history       target_y    -0.682953         0.682953
#
#    threshold
# 0       0.08

# %% [markdown]
# ## 7. Visual Checks

# %%
def plot_predictions(predictions: pd.DataFrame) -> None:
    symbols = predictions["unique_id"].drop_duplicates().tolist()
    fig, axes = plt.subplots(len(symbols), 1, figsize=(14, 4 * len(symbols)), sharex=False)
    if len(symbols) == 1:
        axes = [axes]
    for axis, symbol in zip(axes, symbols, strict=False):
        frame = predictions[predictions["unique_id"] == symbol].sort_values("ds")
        axis.plot(frame["ds"], frame["y"], label="actual", linewidth=2)
        axis.plot(frame["ds"], frame["PECNet"], label="PECNet", linewidth=2)
        axis.set_title(f"{symbol} Tier4 PECNet: Actual vs Prediction")
        axis.legend()
    plt.tight_layout()
    plt.show()


def plot_feature_selection(feature_selection: pd.DataFrame) -> None:
    plot_df = feature_selection.dropna(subset=["abs_correlation"]).copy()
    if plot_df.empty:
        print("No correlation-based feature selection rows to plot.")
        return
    fig, ax = plt.subplots(figsize=(12, 5))
    labels = plot_df["ticker"] + " #" + plot_df["selection_order"].astype(str) + " " + plot_df["feature_name"]
    ax.bar(labels, plot_df["abs_correlation"])
    ax.set_title("Tier4 Residual-Correlation Feature Selection")
    ax.set_ylabel("abs(correlation)")
    ax.tick_params(axis="x", rotation=45)
    plt.tight_layout()
    plt.show()

# %%
plot_predictions(predictions)
plot_feature_selection(feature_selection)

# %% [markdown]
# ## 7.1 PECNet Utility Plot

# %%
def plot_predictions_with_pecnet_utility(predictions: pd.DataFrame) -> None:
    for symbol, frame in predictions.groupby("unique_id", observed=True):
        frame = frame.sort_values("ds")
        Utility.plot(
            frame["ds"].to_numpy(),
            frame["y"].to_numpy(),
            frame["PECNet"].to_numpy(),
            title=f"{symbol} Tier4 PECNet Utility Plot",
            xlabel="Date",
            ylabel="Close",
            tick_size=8,
            labels=["actual", "PECNet"],
        )


plot_predictions_with_pecnet_utility(predictions)

# %% [markdown]
# ## 8. Notes
#
# Bu notebook araştırma amaçlıdır. Production pipeline’daki Feast/Kedro/MLflow/W&B entegrasyonları bilinçli olarak dışarıda bırakıldı. Aynı tier4 fikri pipeline tarafında `ml/pecnet/thesis_selection.py` içinde modüler halde duruyor; burada ise akış okunabilir olsun diye notebook içinde tekrarlandı.
